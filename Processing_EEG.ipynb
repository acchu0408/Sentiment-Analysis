# %% [markdown]
# <a href="https://colab.research.google.com/github/acchu0408/Sentiment-Analysis/blob/main/Processing_EEG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2257388c-4e05-41bc-ae49-81d478f081fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2257388c-4e05-41bc-ae49-81d478f081fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Harshat.csv to Harshat.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['Harshat.csv']))
df.head(20)
# Out:
#                   TimeStamp  Delta_TP9  ...  Battery              Elements
# 0   2021-12-03 00:32:24.073   0.520348  ...     30.0                   NaN
# 1   2021-12-03 00:32:25.083   0.689163  ...     30.0                   NaN
# 2   2021-12-03 00:32:26.090   1.062221  ...     30.0                   NaN
# 3   2021-12-03 00:32:27.099   1.249916  ...     35.0                   NaN
# 4   2021-12-03 00:32:28.104   1.005173  ...     35.0                   NaN
# 5   2021-12-03 00:32:29.104   0.729747  ...     35.0                   NaN
# 6   2021-12-03 00:32:30.106   1.054718  ...     35.0                   NaN
# 7   2021-12-03 00:32:31.112   1.018663  ...     35.0                   NaN
# 8   2021-12-03 00:32:32.125   0.693394  ...     35.0                   NaN
# 9   2021-12-03 00:32:33.139   0.660233  ...     35.0                   NaN
# 10  2021-12-03 00:32:34.149   1.109771  ...     35.0                   NaN
# ...

# %%
df.info()

# %%
df.describe()
# Out:
#         Delta_TP9   Delta_AF7   Delta_AF8  ...     HSI_AF8    HSI_TP10     Battery
# count  467.000000  467.000000  467.000000  ...  467.000000  467.000000  467.000000
# mean     0.917199    0.842963    0.769605  ...    1.012848    1.012848   30.685225
# std      0.297176    0.294803    0.356799  ...    0.196115    0.196115    2.008954
# min      0.000000    0.000000   -0.230616  ...    1.000000    1.000000   25.000000
# 25%      0.727122    0.659519    0.556207  ...    1.000000    1.000000   30.000000
# 50%      0.929831    0.884579    0.817244  ...    1.000000    1.000000   30.000000
# 75%      1.119795    1.040974    1.019925  ...    1.000000    1.000000   30.000000
# max      1.618999    1.543381    1.457286  ...    4.000000    4.000000   35.000000
#
# [8 rows x 37 columns]

# %%
df = df.dropna(axis = 0, subset=['Delta_TP9'])

# %%
df.head(20)
# Out:
#                   TimeStamp  Delta_TP9  Delta_AF7  ...  HSI_TP10  Battery  Elements
# 0   2021-12-03 00:32:24.073   0.520348   0.766189  ...       1.0     30.0       NaN
# 1   2021-12-03 00:32:25.083   0.689163   1.110992  ...       1.0     30.0       NaN
# 2   2021-12-03 00:32:26.090   1.062221   1.044458  ...       1.0     30.0       NaN
# 3   2021-12-03 00:32:27.099   1.249916   0.906737  ...       1.0     35.0       NaN
# 4   2021-12-03 00:32:28.104   1.005173   0.428004  ...       1.0     35.0       NaN
# 5   2021-12-03 00:32:29.104   0.729747   0.577408  ...       1.0     35.0       NaN
# 6   2021-12-03 00:32:30.106   1.054718   0.822109  ...       1.0     35.0       NaN
# 7   2021-12-03 00:32:31.112   1.018663   0.765460  ...       1.0     35.0       NaN
# 8   2021-12-03 00:32:32.125   0.693394   0.734785  ...       1.0     35.0       NaN
# 9   2021-12-03 00:32:33.139   0.660233   0.675853  ...       1.0     35.0       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 467 entries, 0 to 505
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TimeStamp        467 non-null    object
#  1   Delta_TP9        467 non-null    float64
#  2   Delta_AF7        467 non-null    float64
#  3   Delta_AF8        467 non-null    float64
#  4   Delta_TP10       467 non-null    float64
#  5   Theta_TP9        467 non-null    float64
#  6   Theta_AF7        467 non-null    float64
#  7   Theta_AF8        467 non-null    float64
#  8   Theta_TP10       467 non-null    float64
#  9   Alpha_TP9        467 non-null    float64
#  10  Alpha_AF7        467 non-null    float64
#  11  Alpha_AF8        467 non-null    float64
#  12  Alpha_TP10       467 non-null    float64
#  13  Beta_TP9         467 non-null    float64
#  14  Beta_AF7         467 non-null    float64
#  15  Beta_AF8         467 non-null    float64
# ...

# %%
new_delta = df[["TimeStamp", "Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10"]]
new_delta.head()
# Out:
#                  TimeStamp  Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10
# 0  2021-12-03 00:32:24.073   0.520348   0.766189  -0.054635    0.471849
# 1  2021-12-03 00:32:25.083   0.689163   1.110992   0.556937    0.620638
# 2  2021-12-03 00:32:26.090   1.062221   1.044458   0.520900    1.124232
# 3  2021-12-03 00:32:27.099   1.249916   0.906737   0.941150    1.462702
# 4  2021-12-03 00:32:28.104   1.005173   0.428004   0.818002    0.223020

# %%
new_delta.plot()

# %%
new_theta = df[["TimeStamp", "Theta_TP9", "Theta_AF7", "Theta_AF8", "Theta_TP10"]]
new_theta.head()
# Out:
#                  TimeStamp  Theta_TP9  Theta_AF7  Theta_AF8  Theta_TP10
# 0  2021-12-03 00:32:24.073   0.833355   0.396061  -0.430150    0.726212
# 1  2021-12-03 00:32:25.083   0.695096   0.555560   0.234369    0.561136
# 2  2021-12-03 00:32:26.090   0.839688   0.447998   0.192159    0.651756
# 3  2021-12-03 00:32:27.099   0.992752   0.329016   0.585086    0.969816
# 4  2021-12-03 00:32:28.104   0.674301   0.598385   0.502483    0.112730

# %%
new_theta.plot()

# %%
new_alpha = df[["TimeStamp", "Alpha_TP9", "Alpha_AF7", "Alpha_AF8", "Alpha_TP10"]]
new_alpha.head()
# Out:
#                  TimeStamp  Alpha_TP9  Alpha_AF7  Alpha_AF8  Alpha_TP10
# 0  2021-12-03 00:32:24.073   0.939910   0.546117   0.301072    0.881719
# 1  2021-12-03 00:32:25.083   0.871943   0.553013   0.608273    0.940022
# 2  2021-12-03 00:32:26.090   0.920020   0.467938   0.555644    1.222782
# 3  2021-12-03 00:32:27.099   1.006317   0.314677   0.569843    1.222782
# 4  2021-12-03 00:32:28.104   0.986198   0.375129   0.583940    0.713221

# %%
new_alpha.plot()

# %%
new_beta = df[["TimeStamp", "Beta_TP9", "Beta_AF7", "Beta_AF8", "Beta_TP10"]]
new_beta.head()
# Out:
#                  TimeStamp  Beta_TP9  Beta_AF7  Beta_AF8  Beta_TP10
# 0  2021-12-03 00:32:24.073  0.702404  0.528473  0.098015   0.774251
# 1  2021-12-03 00:32:25.083  0.690264  0.636279  0.206831   0.755698
# 2  2021-12-03 00:32:26.090  0.896305  0.656451  0.359728   1.004127
# 3  2021-12-03 00:32:27.099  0.709978  0.606017  0.283522   1.131771
# 4  2021-12-03 00:32:28.104  0.712541  0.275658  0.099212   0.581503

# %%
new_beta.plot()

# %%
new_gamma = df[["TimeStamp", "Gamma_TP9", "Gamma_AF7", "Gamma_AF8", "Gamma_TP10"]]
new_gamma.head()
# Out:
#                  TimeStamp  Gamma_TP9  Gamma_AF7  Gamma_AF8  Gamma_TP10
# 0  2021-12-03 00:32:24.073   0.313432   0.400057  -0.205723    0.314038
# 1  2021-12-03 00:32:25.083   0.537482   0.386938  -0.022118    0.389156
# 2  2021-12-03 00:32:26.090   0.560128   0.282331  -0.030025    0.388685
# 3  2021-12-03 00:32:27.099   0.595593   0.225671  -0.220888    0.442381
# 4  2021-12-03 00:32:28.104   0.588957   0.266560  -0.244831    0.116104

# %%
new_gamma.plot()

# %%
harshat_EEG = pd.read_csv("Harshat.csv")
Amit_EEG = pd.read_csv("Amit.csv")

new1 = harshat_EEG[["TimeStamp", "Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10"]]
new2 = Amit_EEG[["TimeStamp", "Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10"]]

Concat = pd.concat([new1, new2], axis=0)

# %%
Concat.plot(x = "TimeStamp", y = "Delta_TP9", kind="scatter")

# %%
new1.plot(x = "TimeStamp", y = "Delta_TP9", kind="scatter")
new2.plot(x = "TimeStamp", y = "Delta_TP9", kind="scatter")

# %%
sns.scatterplot(x="TimeStamp",y = "Delta_TP9", data=new1 )
sns.scatterplot(x="TimeStamp",y = "Delta_TP10", data=new2)
